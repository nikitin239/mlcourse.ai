# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df.drop('State', axis =1).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f81782c8da0>,
# ...
#       dtype=object)

# %%
df['International plan']= df['International plan'].map({'Yes':1,'No':0})

# %%
df['Voice mail plan']= df['Voice mail plan'].map({'Yes':1,'No':0})

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415                   0                1
# 1    OH             107        415                   0                1
# 2    NJ             137        415                   0                0
# 3    OH              84        408                   1                0
# 4    OK              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
plt.rcParams['figure.figsize']=(16,12)
df.drop(['State'], axis = 1).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f81716976d8>,
# ...
#       dtype=object)

# %%
df.corr()
# Out:
#                         Account length  Area code  International plan  \
# Account length                1.000000  -0.012463            0.024735
# Area code                    -0.012463   1.000000            0.048551
# International plan            0.024735   0.048551            1.000000
# Voice mail plan               0.002918  -0.000747            0.006006
# Number vmail messages        -0.004628  -0.001994            0.008745
# Total day minutes             0.006216  -0.008264            0.049396
# Total day calls               0.038470  -0.009646            0.003755
# Total day charge              0.006214  -0.008264            0.049398
# Total eve minutes            -0.006757   0.003580            0.019100
# Total eve calls               0.019260  -0.011886            0.006114
# Total eve charge             -0.006745   0.003607            0.019106
# Total night minutes          -0.008955  -0.005825           -0.028905
# ...

# %%
sns.heatmap(df.corr())

# %%
[feat_name for feat_name in df.columns if 'charge' in feat_name
]
# Out:
# ['Total day charge',
#  'Total eve charge',
#  'Total night charge',
#  'Total intl charge']

# %%
df.drop([feat_name for feat_name in df.columns if 'charge' in feat_name
], axis =1, inplace =True).shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-4efe36558dba> in <module>()
#       1 df.drop([feat_name for feat_name in df.columns if 'charge' in feat_name
# ----> 2 ], axis =1, inplace =True).shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'
